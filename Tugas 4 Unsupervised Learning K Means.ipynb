# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
mallCustomersDf = pd.read_csv("https://raw.githubusercontent.com/pavankalyan1997/Machine-learning-without-any-libraries/master/2.Clustering/1.K_Means_Clustering/Mall_Customers.csv")
mallCustomersDf
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
def euclidean(array1,array2,b1,b2):
    arrayjarak = []
    for i in range(len(array1)):
        jarak = np.round(((array1[i]-b1)**2)+((array2[i]-b2)**2))
        arrayjarak.append(jarak)
    return arrayjarak

# %%
def knearest(array1,array2,array3,b1,b2):
    traindata = []
    arrayjarak = euclidean(array1,array2,b1,b2)
    traindata.append(array1)
    traindata.append(array2)
    traindata.append(array3)
    traindata.append(arrayjarak)
    return traindata

# %%
mallCustomersDf.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
genre = mallCustomersDf['Genre'].values
genre
# Out:
# array(['Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female',
#        'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male',
#        'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female',
#        'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female',
#        'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male',
#        'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female',
#        'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female',
#        'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female',
#        'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male',
#        'Male', 'Male'], dtype=object)

# %%
income = mallCustomersDf['Annual Income (k$)'].values
income
# Out:
# array([ 15,  15,  16,  16,  17,  17,  18,  18,  19,  19,  19,  19,  20,
#         20,  20,  20,  21,  21,  23,  23,  24,  24,  25,  25,  28,  28,
#         28,  28,  29,  29,  30,  30,  33,  33,  33,  33,  34,  34,  37,
#         37,  38,  38,  39,  39,  39,  39,  40,  40,  40,  40,  42,  42,
#         43,  43,  43,  43,  44,  44,  46,  46,  46,  46,  47,  47,  48,
#         48,  48,  48,  48,  48,  49,  49,  50,  50,  54,  54,  54,  54,
#         54,  54,  54,  54,  54,  54,  54,  54,  57,  57,  58,  58,  59,
#         59,  60,  60,  60,  60,  60,  60,  61,  61,  62,  62,  62,  62,
#         62,  62,  63,  63,  63,  63,  63,  63,  64,  64,  65,  65,  65,
#         65,  67,  67,  67,  67,  69,  69,  70,  70,  71,  71,  71,  71,
#         71,  71,  72,  72,  73,  73,  73,  73,  74,  74,  75,  75,  76,
#         76,  77,  77,  77,  77,  78,  78,  78,  78,  78,  78,  78,  78,
#         78,  78,  78,  78,  79,  79,  81,  81,  85,  85,  86,  86,  87,
#         87,  87,  87,  87,  87,  88,  88,  88,  88,  93,  93,  97,  97,
#         98,  98,  99,  99, 101, 101, 103, 103, 103, 103, 113, 113, 120,
#        120, 126, 126, 137, 137], dtype=int64)

# %%
spending = mallCustomersDf['Spending Score (1-100)'].values
spending
# Out:
# array([39, 81,  6, 77, 40, 76,  6, 94,  3, 72, 14, 99, 15, 77, 13, 79, 35,
#        66, 29, 98, 35, 73,  5, 73, 14, 82, 32, 61, 31, 87,  4, 73,  4, 92,
#        14, 81, 17, 73, 26, 75, 35, 92, 36, 61, 28, 65, 55, 47, 42, 42, 52,
#        60, 54, 60, 45, 41, 50, 46, 51, 46, 56, 55, 52, 59, 51, 59, 50, 48,
#        59, 47, 55, 42, 49, 56, 47, 54, 53, 48, 52, 42, 51, 55, 41, 44, 57,
#        46, 58, 55, 60, 46, 55, 41, 49, 40, 42, 52, 47, 50, 42, 49, 41, 48,
#        59, 55, 56, 42, 50, 46, 43, 48, 52, 54, 42, 46, 48, 50, 43, 59, 43,
#        57, 56, 40, 58, 91, 29, 77, 35, 95, 11, 75,  9, 75, 34, 71,  5, 88,
#         7, 73, 10, 72,  5, 93, 40, 87, 12, 97, 36, 74, 22, 90, 17, 88, 20,
#        76, 16, 89,  1, 78,  1, 73, 35, 83,  5, 93, 26, 75, 20, 95, 27, 63,
#        13, 75, 10, 92, 13, 86, 15, 69, 14, 90, 32, 86, 15, 88, 39, 97, 24,
#        68, 17, 85, 23, 69,  8, 91, 16, 79, 28, 74, 18, 83], dtype=int64)

# %%
traindata = knearest(income,spending,genre,18,94)
df = pd.DataFrame({"Annual Income":traindata[0], 
                   "Spending Score(1-100)":traindata[1],
                   "Genre":traindata[2],
                   "Jarak ke data uji (X1=17,X2=25)":traindata[3]})
df.head(10)
# Out:
#    Annual Income  Spending Score(1-100)   Genre  \
# 0             15                     39    Male
# 1             15                     81    Male
# 2             16                      6  Female
# 3             16                     77  Female
# 4             17                     40  Female
# 5             17                     76  Female
# 6             18                      6  Female
# 7             18                     94  Female
# 8             19                      3    Male
# 9             19                     72  Female
#
#    Jarak ke data uji (X1=17,X2=25)
# 0                             3034
# 1                              178
# 2                             7748
# 3                              293
# 4                             2917
# 5                              325
# 6                             7744
# 7                                0
# 8                             8282
# 9                              485

# %%
result = df.head(10).sort_values(by=['Jarak ke data uji (X1=17,X2=25)'])
result
# Out:
#    Annual Income  Spending Score(1-100)   Genre  \
# 7             18                     94  Female
# 1             15                     81    Male
# 3             16                     77  Female
# 5             17                     76  Female
# 9             19                     72  Female
# 4             17                     40  Female
# 0             15                     39    Male
# 6             18                      6  Female
# 2             16                      6  Female
# 8             19                      3    Male
#
#    Jarak ke data uji (X1=17,X2=25)
# 7                                0
# 1                              178
# 3                              293
# 5                              325
# 9                              485
# 4                             2917
# 0                             3034
# 6                             7744
# 2                             7748
# 8                             8282

# %%
dataTraining = df.head(10)
dataTraining
# Out:
#    Annual Income  Spending Score(1-100)   Genre  \
# 0             15                     39    Male
# 1             15                     81    Male
# 2             16                      6  Female
# 3             16                     77  Female
# 4             17                     40  Female
# 5             17                     76  Female
# 6             18                      6  Female
# 7             18                     94  Female
# 8             19                      3    Male
# 9             19                     72  Female
#
#    Jarak ke data uji (X1=17,X2=25)
# 0                             3034
# 1                              178
# 2                             7748
# 3                              293
# 4                             2917
# 5                              325
# 6                             7744
# 7                                0
# 8                             8282
# 9                              485
