# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def grayscale(img):
    gray = 0.2126 * img[:,:,0] + 0.7152 * img[:,:,1] + 0.2127 * img[:,:,2]
    gray_img = gray.astype(np.uint8)
    return gray_img

# %%
orig = cv2.imread('./data/train/alien/0.jpg')
gray = grayscale(orig)
plt.imshow(gray, cmap='gray')

# %%
import os
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img,(50,50))
        img = grayscale(img)
        if img is not None:
            images.append(img)
    return images

# %%
alien_gray = load_images('./data/train/alien')

# %%
predator_gray = load_images('./data/train/predator')

# %%
f, grayplot = plt.subplots(2,2)
grayplot[0,0].imshow(alien_gray[0], cmap='gray')
grayplot[0,1].imshow(alien_gray[1], cmap='gray')
grayplot[1,0].imshow(predator_gray[0], cmap='gray')
grayplot[1,1].imshow(predator_gray[1], cmap='gray')
plt.show()

# %%
img = alien_gray[0]
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_OTSU)
plt.imshow(thresh1,'binary')
plt.show()

# %%
def sobelOperator(img):
    container = np.copy(img)
    size = container.shape
    for i in range(1, size[0] - 1):
        for j in range(1, size[1] - 1):
            gx = (img[i - 1][j - 1] + 2*img[i][j - 1] + img[i + 1][j - 1]) - (img[i - 1][j + 1] + 2*img[i][j + 1] + img[i + 1][j + 1])
            gy = (img[i - 1][j - 1] + 2*img[i - 1][j] + img[i - 1][j + 1]) - (img[i + 1][j - 1] + 2*img[i + 1][j] + img[i + 1][j + 1])
            container[i][j] = min(255, np.sqrt(gx**2 + gy**2))
    return container
    pass

# %%
image_data = []
image_data = np.asarray(image_data, dtype=np.float32)
len(image_data)
# Out:
# 0

# %%
alien_gray = np.asarray(alien_gray, dtype=np.float32)
len(alien_gray)
# Out:
# 347

# %%
predator_gray = np.asarray(predator_gray, dtype=np.float32)
len(predator_gray)
# Out:
# 347

# %%
labels = []

# %%
for i in alien_gray:
    print(i)
    image_data.append(i)
    labels.append(1)
# Out:
# [[34. 34. 34. ... 34. 34. 34.]
#  [34. 34. 34. ... 34. 34. 34.]
#  [34. 34. 34. ... 34. 34. 34.]
#  ...
#  [34. 34. 34. ... 34. 34. 34.]
#  [34. 34. 34. ... 34. 34. 34.]
#  [34. 34. 34. ... 34. 34. 34.]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9af9be6db7c1> in <module>
#       1 for i in alien_gray:
#       2     print(i)
# ----> 3     image_data.append(i)
#       4     labels.append(1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
len(labels)
