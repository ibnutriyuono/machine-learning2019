# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def grayscale(img):
    gray = 0.2126 * img[:,:,0] + 0.7152 * img[:,:,1] + 0.2127 * img[:,:,2]
    gray_img = gray.astype(np.uint8)
    return gray_img

# %%
orig = cv2.imread('./data/train/alien/0.jpg')
gray = grayscale(orig)
plt.imshow(gray, cmap='gray')

# %%
import os
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.resize(img,(50,50))
#         img = grayscale(img)
        if img is not None:
            images.append(img)
    return images

# %%
alien_gray = load_images('./data/train/alien')

# %%
predator_gray = load_images('./data/train/predator')

# %%
f, grayplot = plt.subplots(2,2)
grayplot[0,0].imshow(alien_gray[0], cmap='gray')
grayplot[0,1].imshow(alien_gray[1], cmap='gray')
grayplot[1,0].imshow(predator_gray[0], cmap='gray')
grayplot[1,1].imshow(predator_gray[1], cmap='gray')
plt.show()

# %%
# img = alien_gray[0]
# ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_OTSU)
# plt.imshow(thresh1,'binary')
# plt.show()

# %%
def sobelOperator(img):
    container = np.copy(img)
    size = container.shape
    for i in range(1, size[0] - 1):
        for j in range(1, size[1] - 1):
            gx = (img[i - 1][j - 1] + 2*img[i][j - 1] + img[i + 1][j - 1]) - (img[i - 1][j + 1] + 2*img[i][j + 1] + img[i + 1][j + 1])
            gy = (img[i - 1][j - 1] + 2*img[i - 1][j] + img[i - 1][j + 1]) - (img[i + 1][j - 1] + 2*img[i + 1][j] + img[i + 1][j + 1])
            container[i][j] = min(255, np.sqrt(gx**2 + gy**2))
    return container
    pass

# %%
image_data = []
image_data = np.asarray(image_data, dtype=np.float32)
len(image_data)
# Out:
# 0

# %%
from skimage.feature import hog
from skimage import data, exposure

# %%
fd, hog_image = hog(orig, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(orig, cmap=plt.cm.gray)
ax1.set_title('Input image')

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap="gray")
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
import sys
# np.set_printoptions(threshold=sys.maxsize)

# %%
fd, hog_image = hog(alien_gray[0], orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(alien_gray[0], cmap=plt.cm.gray)
ax1.set_title('Input image')

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap="gray")
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
def hog_images(array, label):
    images = []
    labels = []
    for i in array:
        fd, hog_image = hog(i, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)
        hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
        images.append(hog_image_rescaled)
        labels.append(label)
    return images, labels

# %%
alien_hog, alien_label =  hog_images(alien_gray,1)

# %%
predator_hog, predator_label =  hog_images(predator_gray,1)
